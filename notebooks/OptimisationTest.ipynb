# %%
import warnings
warnings.filterwarnings('ignore')


import pandas as pd
from fyers_helper import prepare_data, load_stock_data
import datetime as dt

interval = "15"

nifty200_df = pd.read_csv('nifty50.csv')
tickers = [ f'NSE:{n}-EQ' for n in nifty200_df.Symbol.tolist()]

data_path = "../data15m"

end_date = dt.datetime.now()
start_date = dt.datetime(2015, 1, 1)

file_paths = prepare_data(tickers, interval, start_date=start_date, end_date=end_date, path=data_path, overwrite=False)
loaded_data_1D = load_stock_data(file_paths, data_path, interval)

df = pd.concat(loaded_data_1D, names=["Stock", "Date"]).reset_index()
df = df[(df.Date.dt.time >= dt.time(9,15)) & (df.Date.dt.time < dt.time(15,30))]
# Out:
# Downloading data: 100%|██████████| 50/50 [00:00<00:00, 91538.72ticker/s]
# Loading 15min data: 100%|██████████| 50/50 [00:00<00:00, 253.58it/s]

# %%
from lib import Bank, PositionManager, generate_tearsheet
import talib as ta
from tqdm.notebook import tqdm


def backtest(_df, pm: PositionManager, params, show_pb=False):
    max_positions = params['max_positions']
    fast_ma = int(params['fast_ma'])
    slow_ma = int(params['slow_ma'])
    trend_filter_ma = int(params['trend_filter_ma'])
    atr_period = params['atr_period']
    start_date = params['start_date']
    end_date = params['end_date']
    initial_capital = params['initial_capital']

    print(f"fast_ma - {fast_ma}, slow_ma - {slow_ma}")

    _df['FastMA'] = _df.groupby('Stock')['Close'].transform(lambda x: x.rolling(fast_ma).mean())
    _df['SlowMA'] = _df.groupby('Stock')['Close'].transform(lambda x: x.rolling(slow_ma).mean())
    _df['TrendFilterMA'] = _df.groupby('Stock')['Close'].transform(lambda x: x.rolling(trend_filter_ma).mean())

    def calc_atr(group):
        group = group.copy()
        group['ATR'] = ta.ATR(group['High'], group['Low'], group['Close'], atr_period)
        return group

    _df = _df.groupby('Stock', group_keys=False).apply(calc_atr)

    _df["NextTime"] = _df.groupby('Stock')['Date'].shift(-1)
    _df["NextOpen"] = _df.groupby('Stock')['Open'].shift(-1)
    _df["PrevFastMA"] = _df.groupby('Stock')['FastMA'].shift()
    _df["PrevSlowMA"] = _df.groupby('Stock')['SlowMA'].shift()

    _df = _df.dropna().reset_index(drop=True)
    _df = _df[(_df.Date >= start_date) & (_df.Date < end_date)].reset_index()

    _df['signal'] = 0
    _df.loc[(_df.Close > _df.TrendFilterMA) & (_df.FastMA > _df.SlowMA) & (_df.PrevFastMA < _df.PrevSlowMA), 'signal'] = 1
    _df.loc[(_df.Close < _df.TrendFilterMA) & (_df.FastMA < _df.SlowMA) & (_df.PrevFastMA > _df.PrevSlowMA), 'signal'] = -1

    signals = _df[_df.signal != 0]

    if show_pb:
        pb = tqdm(total=_df.Date.nunique(), desc="Backtesting...")

    for idx, group in _df.groupby('Date'):
        day_signals = signals[signals.Date == idx]
        for signal in day_signals.itertuples():
            if pm.get_position(signal.Stock) is None:
                capital = round(pm.bank.total_capital() / max_positions, 2)
                position = pm.new_position(signal.Stock, signal.NextTime, signal.NextOpen, capital)
                if position is not None:
                    position.tp = position.avg_entry_price + signal.ATR * 2
                    position.sl = position.avg_entry_price - signal.ATR * 1


        for position in pm.get_active_positions():
            stock = group[group.Stock == position.stock]
            if stock.empty:
                continue
            try:
                if (stock.Close.iloc[0] >= position.tp) or (stock.Close.iloc[0] <= position.sl):
                    pm.close_position(position.stock, idx, stock.Close.iloc[0])
            except Exception as e:
                print(f"stock.Close - {stock.Close}")
                print(f"stock - {stock}")
                print(f"position - {position}")
                print(f"idx - {idx}")
                print(f"group - {group}")
                raise e

        if show_pb:
            pb.update(1)

    if show_pb:
        pb.close()
    
    return generate_tearsheet(initial_capital, pm)

# %%
from lib import optimize

CONSTANT_PARAMS = {
    'initial_capital': 100000,
    "max_positions": 10,
    "atr_period": 40,
    'trend_filter_ma': 100,
    'start_date': '2024-12-01',
    'end_date': '2025-04-01'
}

if __name__ == '__main__':
    # Optuna parameter space: each param dicts its type/range for the Optuna objective logic
    space = {
        "fast_ma": {"type": "int", "low": 10, "high": 50, 'step': 5},    # step feature should be handled in the objective
        "slow_ma": {"type": "int", "low": 50, "high": 100, 'step': 5},
        # "trend_filter_ma": {"type": "int", "low": 100, "high": 600, "step": 50}, # if needed
    }

    study = optimize(backtest, df, space, CONSTANT_PARAMS, max_evals=20, n_jobs=-1)
    print("Best parameters:", study.best_params)
    print("Best objective:", study.best_value)
# Out:
# Optimizing:   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2025-10-02 15:35:12,150] A new study created in memory with name: no-name-3abada0c-f43e-4c23-a9e6-55ce006c63ac
# fast_ma - 50, slow_ma - 90
# fast_ma - 35, slow_ma - 90
# fast_ma - 50, slow_ma - 80
# fast_ma - 40, slow_ma - 90
# fast_ma - 35, slow_ma - 95
# fast_ma - 35, slow_ma - 90
# fast_ma - 15, slow_ma - 50
# fast_ma - 30, slow_ma - 95
# fast_ma - 50, slow_ma - 90
# fast_ma - 15, slow_ma - 90
# [W 2025-10-02 15:36:11,033] Trial 3 failed with parameters: {'fast_ma': 35, 'slow_ma': 90} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:11,173] Trial 5 failed with parameters: {'fast_ma': 50, 'slow_ma': 90} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:11,305] Trial 3 failed with value None.
# [W 2025-10-02 15:36:11,456] Trial 7 failed with parameters: {'fast_ma': 50, 'slow_ma': 90} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:11,611] Trial 1 failed with parameters: {'fast_ma': 40, 'slow_ma': 90} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:12,203] Trial 5 failed with value None.
# [W 2025-10-02 15:36:12,632] Trial 7 failed with value None.
# [W 2025-10-02 15:36:12,799] Trial 1 failed with value None.
# fast_ma - 10, slow_ma - 60
# [W 2025-10-02 15:36:13,142] Trial 4 failed with parameters: {'fast_ma': 35, 'slow_ma': 90} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:13,433] Trial 9 failed with parameters: {'fast_ma': 30, 'slow_ma': 95} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:13,747] Trial 8 failed with parameters: {'fast_ma': 50, 'slow_ma': 80} because of the following error: The value None could not be cast to float..
# fast_ma - 25, slow_ma - 95
# fast_ma - 35, slow_ma - 70
# fast_ma - 20, slow_ma - 95
# [W 2025-10-02 15:36:14,043] Trial 4 failed with value None.
# [W 2025-10-02 15:36:14,232] Trial 9 failed with value None.
# [W 2025-10-02 15:36:14,266] Trial 8 failed with value None.
# [W 2025-10-02 15:36:14,376] Trial 2 failed with parameters: {'fast_ma': 35, 'slow_ma': 95} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:14,877] Trial 2 failed with value None.
# fast_ma - 20, slow_ma - 100
# fast_ma - 25, slow_ma - 95
# fast_ma - 45, slow_ma - 65
# fast_ma - 30, slow_ma - 65
# [W 2025-10-02 15:36:16,214] Trial 0 failed with parameters: {'fast_ma': 15, 'slow_ma': 50} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:16,245] Trial 0 failed with value None.
# fast_ma - 20, slow_ma - 85
# [W 2025-10-02 15:36:16,902] Trial 6 failed with parameters: {'fast_ma': 15, 'slow_ma': 90} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:36:16,907] Trial 6 failed with value None.
# fast_ma - 35, slow_ma - 70
# [W 2025-10-02 15:37:07,847] Trial 17 failed with parameters: {'fast_ma': 30, 'slow_ma': 65} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:08,177] Trial 17 failed with value None.
# [W 2025-10-02 15:37:09,262] Trial 15 failed with parameters: {'fast_ma': 25, 'slow_ma': 95} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:09,863] Trial 15 failed with value None.
# [W 2025-10-02 15:37:10,218] Trial 13 failed with parameters: {'fast_ma': 20, 'slow_ma': 95} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:10,803] Trial 13 failed with value None.
# [W 2025-10-02 15:37:11,589] Trial 12 failed with parameters: {'fast_ma': 35, 'slow_ma': 70} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:11,756] Trial 12 failed with value None.
# [W 2025-10-02 15:37:12,132] Trial 19 failed with parameters: {'fast_ma': 35, 'slow_ma': 70} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:12,465] Trial 19 failed with value None.
# [W 2025-10-02 15:37:13,456] Trial 14 failed with parameters: {'fast_ma': 20, 'slow_ma': 100} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:13,657] Trial 14 failed with value None.
# [W 2025-10-02 15:37:13,902] Trial 18 failed with parameters: {'fast_ma': 20, 'slow_ma': 85} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:13,997] Trial 18 failed with value None.
# [W 2025-10-02 15:37:14,250] Trial 11 failed with parameters: {'fast_ma': 25, 'slow_ma': 95} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:14,673] Trial 11 failed with value None.
# [W 2025-10-02 15:37:15,314] Trial 16 failed with parameters: {'fast_ma': 45, 'slow_ma': 65} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:15,396] Trial 16 failed with value None.
# [W 2025-10-02 15:37:15,646] Trial 10 failed with parameters: {'fast_ma': 10, 'slow_ma': 60} because of the following error: The value None could not be cast to float..
# [W 2025-10-02 15:37:15,647] Trial 10 failed with value None.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 21
#      14 space = {
#      15     "fast_ma": {"type": "int", "low": 10, "high": 50, 'step': 5},    # step feature should be handled in the objective
#      16     "slow_ma": {"type": "int", "low": 50, "high": 100, 'step': 5},
#      17     # "trend_filter_ma": {"type": "int", "low": 100, "high": 600, "step": 50}, # if needed
#      18 }
#      20 study = optimize(backtest, df, space, CONSTANT_PARAMS, max_evals=20, n_jobs=-1)
# ---> 21 print("Best parameters:", study.best_params)
#      22 print("Best objective:", study.best_value)
#
# File ~/code/strategy-notebooks/.venv/lib/python3.10/site-packages/optuna/study/study.py:120, in Study.best_params(self)
#     108 @property
#     109 def best_params(self) -> dict[str, Any]:
#     110     """Return parameters of the best trial in the study.
#     111
#     112     .. note::
#    (...)
#     117
#     118     """
# --> 120     return self.best_trial.params
#
# File ~/code/strategy-notebooks/.venv/lib/python3.10/site-packages/optuna/study/study.py:156, in Study.best_trial(self)
#     139 @property
#     140 def best_trial(self) -> FrozenTrial:
#     141     """Return the best trial in the study.
#     142
#     143     .. note::
#    (...)
#     154
#     155     """
# --> 156     return self._get_best_trial(deepcopy=True)
#
# File ~/code/strategy-notebooks/.venv/lib/python3.10/site-packages/optuna/study/study.py:308, in Study._get_best_trial(self, deepcopy)
#     302 if self._is_multi_objective():
#     303     raise RuntimeError(
#     304         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     305         "using Study.best_trials to retrieve a list containing the best trials."
#     306     )
# --> 308 best_trial = self._storage.get_best_trial(self._study_id)
#     310 # If the trial with the best value is infeasible, select the best trial from all feasible
#     311 # trials. Note that the behavior is undefined when constrained optimization without the
#     312 # violation value in the best-valued trial.
#     313 constraints = best_trial.system_attrs.get(_CONSTRAINTS_KEY)
#
# File ~/code/strategy-notebooks/.venv/lib/python3.10/site-packages/optuna/storages/_in_memory.py:252, in InMemoryStorage.get_best_trial(self, study_id)
#     249 best_trial_id = self._studies[study_id].best_trial_id
#     251 if best_trial_id is None:
# --> 252     raise ValueError("No trials are completed yet.")
#     253 elif len(self._studies[study_id].directions) > 1:
#     254     raise RuntimeError(
#     255         "Best trial can be obtained only for single-objective optimization."
#     256     )
#
# ValueError: No trials are completed yet.

# %%
from lib import Bank, PositionManager, show_equity_curve

params = {
    'initial_capital': 100000,
    "max_positions": 10,
    "trend_filter_ma": 200,
    "atr_period": 40,
    'start_date': '2024-12-01',
    'end_date': '2025-04-01',
    'fast_ma': 40,
    'slow_ma': 60
}


bank = Bank(params['initial_capital'])
pm = PositionManager(bank)

tearsheet, trades = backtest(df.copy(), pm, params, show_pb=True)
print(pd.DataFrame({
    "Metrics": tearsheet.keys(),
    "Values": tearsheet.values(),
}))
show_equity_curve(trades)

# %%
min_in_sample_return = 0.005
mean_return = trades['returns'].mean()

if mean_return < min_in_sample_return:
    # Penalize unprofitable parameter combinations
    print({'loss': float('inf'), 'status': "STATUS_OK"})
